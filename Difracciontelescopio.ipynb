# %% [markdown]
# # Ejercicio difracción telescopio

# %% [markdown]
# # Funciones de Bessel

# %%
from numpy import cos,sin,pi
from pylab import *

def J(m,x):
    
    def f(teta):
        return cos(m*teta - x*sin(teta))
    
    N = 1000
    a = 0.
    b = pi
    h = (b-a)/N
    
    q = f(a) + f(b) + 4*f(b-h)
    for k in range(1,N//2):
        q += 4*f(a + (2*k-1)*h) + 2*f(a+2*k*h)
    
    I = h/3*q/pi
    print(I)
    
    return I

x = linspace(0,20)

plot(x,J(0,x),label='J0')
plot(x,J(1,x),label='J1')
plot(x,J(2,x),label='J2')
legend()
# Out:
# [ 1.          0.95878235  0.8402143   0.65885391  0.4367428   0.20040922
#  -0.02270718 -0.20789969 -0.33639369 -0.39765614 -0.39050503 -0.3228862
#  -0.21038026 -0.0736848   0.06453863  0.18297968  0.26467058  0.2992276
#   0.28403825  0.2242539   0.13162938  0.02242192 -0.08530309 -0.17453285
#  -0.23189508 -0.24958799 -0.2263792  -0.1675504  -0.0838308   0.01048359
#   0.09990686  0.17025092  0.2108314   0.21605428  0.18615133  0.12697227
#   0.04889172 -0.03497259 -0.11093063 -0.16692561 -0.19442316 -0.18969127
#  -0.15428167 -0.09465434 -0.02102451  0.05436617  0.11926538  0.16338378
#   0.1800114   0.16702466]
# [ -2.61124455e-16   1.99861102e-01   3.75094864e-01   5.04445775e-01
#    5.72917243e-01   5.73760899e-01   5.09287613e-01   3.90393213e-01
#    2.34880295e-01   6.48325756e-02  -9.65660246e-02  -2.28299020e-01
#   -3.14397012e-01  -3.46018999e-01  -3.22449389e-01  -2.50889909e-01
#   -1.45106140e-01  -2.31570448e-02   9.54327230e-02   1.92622816e-01
#    2.54486381e-01   2.73134020e-01   2.47663662e-01   1.84021395e-01
#    9.38262612e-02  -7.63168049e-03  -1.03889967e-01  -1.79911353e-01
#   -2.24377806e-01  -2.31335331e-01  -2.00953130e-01  -1.39303818e-01
#   -5.72257405e-02   3.15301632e-02   1.12559827e-01   1.73106716e-01
#    2.04040800e-01   2.01212068e-01   1.65980258e-01   1.04856883e-01
#    2.83371792e-02  -5.08740082e-02  -1.19946883e-01  -1.67983481e-01
#   -1.87719731e-01  -1.76609109e-01  -1.37128023e-01  -7.62702409e-02
#   -4.32767753e-03   6.68331242e-02]
# [  6.09882515e-17   2.05370465e-02   7.87681192e-02   1.65074191e-01
#    2.65080818e-01   3.61876459e-01   4.38625399e-01   4.81174938e-01
#    4.80257867e-01   4.32953880e-01   3.43187681e-01   2.21189368e-01
#    8.20014782e-02  -5.67377463e-02  -1.77395918e-01  -2.64937053e-01
#   -3.09109331e-01  -3.05902275e-01  -2.58059339e-01  -1.74577490e-01
#   -6.92802189e-02   4.13093474e-02   1.40464538e-01   2.13737411e-01
#    2.51051270e-01   2.48092184e-01   2.06799937e-01   1.34899825e-01
#    4.45646790e-02  -4.95712795e-02  -1.32729202e-01  -1.92269910e-01
#   -2.19594095e-01  -2.11372527e-01  -1.69929477e-01  -1.02737330e-01
#   -2.11195035e-02   6.16195922e-02   1.32333349e-01   1.80099939e-01
#    1.97894460e-01   1.83611201e-01   1.40287871e-01   7.55120400e-02
#    1.19362599e-04  -7.35969410e-02  -1.33872494e-01  -1.71335363e-01
#   -1.80453188e-01  -1.60341352e-01]

# %% [markdown]
# # b) La gráfica de densidad

# %%
from numpy import cos,sin,pi,sqrt
from pylab import *

def J(m,x):	
    
    def f(teta):
        return cos(m*teta - x*sin(teta))
    
    N = 1000
    a = 0.
    b = pi
    h = (b-a)/N
    
    s = f(a) + f(b) + 4*f(b-h)
    for k in range(1,N//2):
        s += 4*f(a + (2*k-1)*h) + 2*f(a+2*k*h)
    
    I = h/3*s/pi
    
    return I

x,y = mgrid[-1:1:100j,-1:1:100j]
r = sqrt(x**2 + y**2)
longitudeonda = 0.5
k = 2*pi/longitudeonda

I = (J(1,r*k)/k/r)**2
gray()
imshow(I,vmax=0.1/10,extent=(-1,1,-1,1))
